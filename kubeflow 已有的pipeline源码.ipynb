# %%
from typing import NamedTuple

import kfp
from kfp.components import func_to_container_op, InputPath, OutputPath


@func_to_container_op
def add_double(
        output_text_path: OutputPath(str), params1: int = 0, params2: int = 0):
    print("step in add_double")
    with open(output_text_path, 'w') as writer:
        writer.write(params1 + params2)


@func_to_container_op
def add_single(text_path: InputPath(),
               output_text_path: OutputPath(str),
               params1: int = 0):
    print("step in add_single")
    params2 = 0
    f = open(text_path)
    params2 = int(f.readline())
    with open(output_text_path, 'w') as writer:
        writer.write(params1 + params2)


def pipeline_my_handle():
    res1 = add_double(params1=10, params2=10)
    res2 = add_single(text_path=res1.output, params1=1)
    print(res2)


kfp.compiler.Compiler().compile(pipeline_my_handle, "caclulate.yaml")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-90a5d16a3075> in <module>
#      31
#      32
# ---> 33 kfp.compiler.Compiler().compile(pipeline_my_handle, "caclulate.yaml")
#
# /opt/conda/lib/python3.8/site-packages/kfp/compiler/compiler.py in compile(self, pipeline_func, package_path, type_check, pipeline_conf)
#    1051     try:
#    1052       kfp.TYPE_CHECK = type_check
# -> 1053       self._create_and_write_workflow(
#    1054           pipeline_func=pipeline_func,
#    1055           pipeline_conf=pipeline_conf,
#
# /opt/conda/lib/python3.8/site-packages/kfp/compiler/compiler.py in _create_and_write_workflow(self, pipeline_func, pipeline_name, pipeline_description, params_list, pipeline_conf, package_path)
#    1104   ) -> None:
#    1105     """Compile the given pipeline function and dump it to specified file format."""
# -> 1106     workflow = self._create_workflow(
#    1107         pipeline_func,
#    1108         pipeline_name,
#
# /opt/conda/lib/python3.8/site-packages/kfp/compiler/compiler.py in _create_workflow(self, pipeline_func, pipeline_name, pipeline_description, params_list, pipeline_conf)
#     894
#     895     with dsl.Pipeline(pipeline_name) as dsl_pipeline:
# --> 896       pipeline_func(*args_list, **kwargs_dict)
#     897
#     898     pipeline_conf = pipeline_conf or dsl_pipeline.conf # Configuration passed to the compiler is overriding. Unfortunately, it's not trivial to detect whether the dsl_pipeline.conf was ever modified.
#
# <ipython-input-9-90a5d16a3075> in pipeline_my_handle()
#      27 def pipeline_my_handle():
#      28     res1 = add_double(params1=10, params2=10)
# ---> 29     res2 = add_single(text_path=res1.output, params1=1)
#      30     print(res2)
#      31
#
# TypeError: Add single() got an unexpected keyword argument 'text_path'
